# %%
import pandas as pd
import seaborn as seaborn

# %%
sp500 = pd.read_csv("../dataset/sp500_data.csv")
sectors = pd.read_csv("../dataset/sp500_sectors.csv")

# %%
sp500.tail(10)
# Out:
#       Unnamed: 0        ADS        CA      MSFT       RHT      CTSH       CSC  \
# 5637  2015-06-18   2.419983  0.280001  0.500000  0.279999  0.880001  0.300003
# 5638  2015-06-19   2.089996 -0.130001 -0.690003 -0.099999 -0.699997  0.220001
# 5639  2015-06-22   1.540009  0.440001 -0.100002 -0.309998  0.250000 -0.709999
# 5640  2015-06-23  -2.080017  0.040001 -0.220001 -0.159996  0.080002 -0.200004
# 5641  2015-06-24  -0.809997 -0.160000 -0.029999 -0.940002 -0.210000 -0.610001
# 5642  2015-06-25   0.019989 -0.529999 -0.379997  0.080002  0.350003 -0.580002
# 5643  2015-06-26  -1.299988 -0.330000 -0.390004 -1.820000  0.190003  0.330002
# 5644  2015-06-29 -10.299988 -0.410000 -0.670002 -1.250000 -1.919998 -0.510002
# 5645  2015-06-30  -2.109986 -0.049999 -0.559997 -0.099999 -0.689999 -0.610001
# 5646  2015-07-01  -1.210022  0.020000 -0.009998  0.869995  0.329998 -0.190003
#
#            EMC       IBM       XRX  ...       WAT      ALXN      AMGN  \
# ...

# %%
it_companies = sp500.loc[sp500["Unnamed: 0"]>"2012-07-01",sectors[sectors["sector"]=="information_technology"]["symbol"]]
filtered_companies = it_companies.loc[:,"ADS":"IBM"]

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 921 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
it_companies.corr()
# Out:
#            ADS        CA      MSFT       RHT      CTSH       CSC       EMC  \
# ADS   1.000000  0.317587  0.313185  0.372230  0.415668  0.313965  0.252427
# CA    0.317587  1.000000  0.386842  0.425571  0.374354  0.320664  0.330747
# MSFT  0.313185  0.386842  1.000000  0.367569  0.335412  0.314805  0.344778
# RHT   0.372230  0.425571  0.367569  1.000000  0.416278  0.292783  0.398705
# CTSH  0.415668  0.374354  0.335412  0.416278  1.000000  0.345832  0.310101
# ...        ...       ...       ...       ...       ...       ...       ...
# WU    0.283053  0.290681  0.251438  0.302116  0.264646  0.241610  0.272568
# YHOO  0.371072  0.292811  0.273312  0.334899  0.321835  0.263955  0.328125
# CSCO  0.290638  0.449544  0.444759  0.392943  0.397254  0.374167  0.390350
# FFIV  0.323200  0.391833  0.310814  0.474397  0.348185  0.308417  0.360914
# JNPR  0.211987  0.334439  0.262722  0.345901  0.300284  0.252379  0.328836
#
# ...

# %%
sns.heatmap(it_companies.corr(),vmin=-1,vmax=1,annot=True,figsize=(10,10),cmap=sns.diverging_palette(10, 240, n=12,as_cmap=True))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sb/30311bq16l911lpqttfpzgdw0000gn/T/ipykernel_27023/3308304051.py in <module>
# ----> 1 sns.heatmap(it_companies.corr(),vmin=-1,vmax=1,annot=True,figsize=(10,10),cmap=sns.diverging_palette(10, 240, n=12,as_cmap=True))
#
# /opt/homebrew/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/homebrew/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
#     552         ax.set_aspect("equal")
# ...

# %%
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 20))
    sns.heatmap(filtered_companies.corr(),vmin=-1,vmax=1,cmap=sns.diverging_palette(10, 240, n=12,as_cmap=True))

# %%
# Scatterplot
# Salvador
